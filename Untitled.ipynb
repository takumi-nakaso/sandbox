# %%
from IPython.display import HTML

# %%
HTML('<p style="color:red">hoge<script>alert("fuga")</script>piyo</p>')
# Out:
# <p style="color:red">hoge<script>alert("fuga")</script>piyo</p>

# %%
HTML('<p style="color:red">hoge<noscript>fuga</noscript>piyo</p>')
# Out:
# <p style="color:red">hoge<noscript>fuga</noscript>piyo</p>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.io import push_notebook, output_notebook
from bokeh.io.export import get_screenshot_as_png
output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)

# show the results
show(p)
get_screenshot_as_png(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d48ce236-f325-41ca-9d9a-8c906665b9b3">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="230fa410-853b-4e64-b14f-623ad04f2f88"></div>
# </div>
# /Users/nakaso/.anyenv/envs/pyenv/versions/miniconda3-latest/envs/quml/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# <PIL.Image.Image image mode=RGBA size=400x400 at 0x1151F0E48>
